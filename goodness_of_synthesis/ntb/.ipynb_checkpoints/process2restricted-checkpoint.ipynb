# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
df_=pd.read_stata('../HRS-HCAP-Classification/HCAPHRS.dta')
df_=df_.set_index('HHID')
df_
# Out:
#          PN  SECU  STRATUM   PWGTR  HCAP16WGTR  PINSAMP  PIWWAVE  PIWYEAR  \
# HHID
# 010001  010   2.0      1.0  7558.0         NaN      1.0      1.0   2016.0
# 010003  030   2.0      1.0  6900.0         NaN      1.0      1.0   2016.0
# 010004  040   2.0      1.0  5836.0     17148.0      1.0      1.0   2016.0
# 010013  040   2.0      1.0  5768.0         NaN      1.0      1.0   2016.0
# 010038  010   2.0      2.0  6573.0     16431.0      1.0      1.0   2016.0
# ...     ...   ...      ...     ...         ...      ...      ...      ...
# 923525  010   1.0     51.0  1214.0         NaN      1.0      1.0   2016.0
# 923525  020   1.0     51.0  1477.0         NaN      1.0      1.0   2017.0
# 952836  010   2.0     12.0  1041.0         NaN      1.0      1.0   2016.0
# 958361  010   2.0      7.0  2028.0         NaN      1.0      1.0   2016.0
# 959738  010   1.0     20.0   800.0         NaN      1.0      1.0   2016.0
#
#         PMARST  PNURSHM  ...  x3x4  x3x5  x3x6      x3x7      x4x5      x4x6  \
# HHID                     ...
# 010001     4.0      5.0  ...   0.0   0.0   0.0  0.000000 -0.056281 -0.045795
# 010003     3.0      5.0  ...   0.0   0.0   0.0  0.000000 -0.056281 -0.045795
# 010004     3.0      5.0  ...   0.0   0.0   0.0  0.000000 -0.056281 -0.045795
# 010013     2.0      5.0  ...   0.0   0.0   0.0  0.000000 -0.056281 -0.045795
# 010038     1.0      5.0  ...   0.0   0.0   0.0  0.006944 -0.056281 -0.045795
# ...        ...      ...  ...   ...   ...   ...       ...       ...       ...
# 923525     1.0      5.0  ...   0.0   0.0   0.0  0.000000  0.943719 -0.045795
# 923525     1.0      5.0  ...   0.0   0.0   0.0  0.000000 -0.056281 -0.045795
# 952836     2.0      5.0  ...   0.0   0.0   0.0 -0.000000 -0.056281  0.954205
# 958361     2.0      5.0  ...   0.0   0.0   0.0 -0.000000 -0.056281 -0.045795
# 959738     2.0      5.0  ...   0.0   0.0   0.0  0.000000 -0.056281 -0.045795
#
#         x4x7  x5x6  x5x7  x6x7
# HHID
# 010001   0.0   0.0   0.0   0.0
# 010003   4.0   0.0   0.0   0.0
# 010004   0.0   0.0   0.0   0.0
# 010013   1.0   0.0   0.0   0.0
# 010038   0.0   0.0   0.0   0.0
# ...      ...   ...   ...   ...
# 923525   2.0   0.0   2.0   0.0
# 923525   0.0   0.0   0.0   0.0
# 952836  -6.0   0.0  -0.0  -6.0
# 958361  -0.0   0.0  -1.0  -0.0
# 959738   0.0   0.0   0.0   0.0
#
# [19699 rows x 87 columns]

# %%
df_.columns
# Out:
# Index(['PN', 'SECU', 'STRATUM', 'PWGTR', 'HCAP16WGTR', 'PINSAMP', 'PIWWAVE',
#        'PIWYEAR', 'PMARST', 'PNURSHM', 'PPROXY', 'rage', 'PA019', 'PAGE',
#        'female', 'black', 'hisp', 'SCHLYRS', 'HISPANIC', 'RACE', 'vdori',
#        'vdlfl1z', 'vdlfl2', 'vdlfl3', 'vdwdimmz', 'vdwddelz', 'vdexf7z',
#        'vdsevens', 'vdcount', 'nPG014', 'nPG021', 'nPG023', 'nPG030', 'nPG040',
#        'nPG041', 'nPG044', 'nPG047', 'nPG050', 'nPG059', 'PD102', 'jorm',
#        'vs1hcapdx', 'vs1hcapdxeap', 'nonzeroweight', 'inHCAP', 'age65up',
#        'cogfunction2016', 'PrDem', 'PrCIND', 'PrNorm', 'Cog', 'CogSd',
#        'Hudomiet_classification', 'SCHLYRSimp', 'DEGREE', 'spage1', 'spage2',
#        'spage3', 'rage_cat', 'Sex', 'RaceAndEthnicity',
#        'Educational_Attainment', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7',
#        'x1x4', 'x1x5', 'x1x6', 'x1x7', 'x2x4', 'x2x5', 'x2x6', 'x2x7', 'x3x4',
#        'x3x5', 'x3x6', 'x3x7', 'x4x5', 'x4x6', 'x4x7', 'x5x6', 'x5x7', 'x6x7'],
#       dtype='object')

# %%
cols_ignore=['SECU', 'PN','STRATUM','PINSAMP', 'HCAP16WGTR','PIWWAVE',
             'PIWYEAR','PPROXY','rage','PA019','PAGE','x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7',
       'x1x4', 'x1x5', 'x1x6', 'x1x7', 'x2x4', 'x2x5', 'x2x6', 'x2x7', 'x3x4',
       'x3x5', 'x3x6', 'x3x7', 'x4x5', 'x4x6', 'x4x7', 'x5x6', 'x5x7', 'x6x7','SCHLYRSimp',
          'spage1', 'spage2','spage3' ]

# %%
df_=df_[[x for x in df_.columns if x not in cols_ignore]]

# %%
df_.columns
# Out:
# Index(['PWGTR', 'PMARST', 'PNURSHM', 'female', 'black', 'hisp', 'SCHLYRS',
#        'HISPANIC', 'RACE', 'vdori', 'vdlfl1z', 'vdlfl2', 'vdlfl3', 'vdwdimmz',
#        'vdwddelz', 'vdexf7z', 'vdsevens', 'vdcount', 'nPG014', 'nPG021',
#        'nPG023', 'nPG030', 'nPG040', 'nPG041', 'nPG044', 'nPG047', 'nPG050',
#        'nPG059', 'PD102', 'jorm', 'vs1hcapdx', 'vs1hcapdxeap', 'nonzeroweight',
#        'inHCAP', 'age65up', 'cogfunction2016', 'PrDem', 'PrCIND', 'PrNorm',
#        'Cog', 'CogSd', 'Hudomiet_classification', 'DEGREE', 'rage_cat', 'Sex',
#        'RaceAndEthnicity', 'Educational_Attainment'],
#       dtype='object')

# %%
df_['bineduc']=df_['Educational_Attainment'].isin(['Education beyond college','Some college'])+0
df_=df_.drop('Educational_Attainment',axis=1)
# Out:
# /tmp/ipykernel_716809/2680784714.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_['bineduc']=df_['Educational_Attainment'].isin(['Education beyond college','Some college'])+0

# %%
df=df_.copy()
N=26
# Step 1: Select columns with > N unique entries
cols_to_process = [col for col in df.columns if df[col].nunique() > N]

# Step 2: Round/cluster each selected column to N closest values
for col in cols_to_process:
    unique_vals = np.linspace(df[col].min(), df[col].max(), N)  # N evenly spaced values
    df[col] = df[col].apply(lambda x: unique_vals[np.argmin(np.abs(unique_vals - x))])
df
# Out:
#           PWGTR  PMARST  PNURSHM  female  black  hisp  SCHLYRS  HISPANIC  \
# HHID
# 010001  7797.12     4.0      5.0     0.0    0.0   0.0     12.0       5.0
# 010003  7797.12     3.0      5.0     1.0    0.0   0.0     16.0       5.0
# 010004  5847.84     3.0      5.0     1.0    0.0   0.0     12.0       5.0
# 010013  5847.84     2.0      5.0     1.0    0.0   0.0     13.0       5.0
# 010038  5847.84     1.0      5.0     0.0    0.0   0.0     16.0       5.0
# ...         ...     ...      ...     ...    ...   ...      ...       ...
# 923525  1949.28     1.0      5.0     1.0    1.0   0.0     14.0       5.0
# 923525  1949.28     1.0      5.0     0.0    1.0   0.0     12.0       5.0
# 952836  1949.28     2.0      5.0     1.0    0.0   1.0      6.0       2.0
# 958361  1949.28     2.0      5.0     0.0    1.0   0.0     11.0       5.0
# 959738     0.00     2.0      5.0     0.0    0.0   0.0     13.0       5.0
#
#         RACE  vdori  ...    PrCIND  PrNorm       Cog     CogSd  \
# HHID                 ...
# 010001   1.0    4.0  ...  0.000000    1.00  1.867870  0.382113
# 010003   1.0    NaN  ...  0.000000    0.00 -3.824488  0.250356
# 010004   1.0    4.0  ...  0.000000    1.00  2.167467  0.368938
# 010013   1.0    4.0  ...  0.000000    1.00  1.867870  0.408465
# 010038   1.0    3.0  ...  0.000000    1.00  1.867870  0.368938
# ...      ...    ...  ...       ...     ...       ...       ...
# 923525   2.0    NaN  ...  0.000000    0.00 -3.824488  0.250356
# 923525   2.0    NaN  ...  0.000000    0.00 -3.824488  0.250356
# 952836   1.0    NaN  ...  0.000000    0.00 -3.824488  0.250356
# 958361   2.0    NaN  ...  0.000000    0.00 -3.824488  0.250356
# 959738   0.0    4.0  ...  0.266852    0.72  1.268674  0.487519
#
#         Hudomiet_classification  DEGREE  rage_cat     Sex  \
# HHID
# 010001                   Normal     2.0     75-79    Male
# 010003                      NaN     5.0       NaN  Female
# 010004                   Normal     2.0     70-74  Female
# 010013                   Normal     2.0     65-69  Female
# 010038                   Normal     4.0     75-79    Male
# ...                         ...     ...       ...     ...
# 923525                      NaN     2.0       NaN  Female
# 923525                      NaN     1.0       NaN    Male
# 952836                      NaN     0.0       NaN  Female
# 958361                      NaN     1.0       NaN    Male
# 959738                   Normal     2.0     65-69    Male
#
#                                 RaceAndEthnicity  bineduc
# HHID
# 010001                                     White        0
# 010003                                     White        1
# 010004                                     White        0
# 010013                                     White        1
# 010038                                     White        1
# ...                                          ...      ...
# 923525  Black or African-American (Not Hispanic)        1
# 923525  Black or African-American (Not Hispanic)        0
# 952836               Hispanic (any racial group)        0
# 958361  Black or African-American (Not Hispanic)        0
# 959738                   All other racial groups        1
#
# [19699 rows x 47 columns]

# %%
df=df.astype(str).replace('nan','')

# %%
S=10000
df_training=df.sample(S)
training_index=df_training.index.values
df_test = df.drop(df_training.index)

# %%
X=df_training.values.astype(str)
feature_names=df_training.columns

# %%
from quasinet.qnet import load_qnet
from quasinet.qnet import save_qnet
from quasinet.qsampling import qsample
from quasinet.qnet import qdistance, qdistance_matrix
from quasinet.qnet import Qnet

# %%
# %%time
model=Qnet(feature_names=feature_names,alpha=.15)
model.fit(X)
save_qnet(model,'modelbin',gz=True)
# Out:
# CPU times: user 1min 37s, sys: 9.29 s, total: 1min 46s
# Wall time: 1min 47s

# %%
model.training_index=training_index
#save_qnet(model,'modelbin',gz=True)

# %%
OUTDIR='treesbin/'
modelpath='modelbin.gz'
model=load_qnet(modelpath,gz=True)
model.viz_trees(tree_path=OUTDIR,big_enough_threshold=1,format='png')

# %%
NULL=np.array(['']*len(feature_names)).astype('U100')

# %%
X_test=df_test.values.astype(str)

# %%
exposure_index=np.where(feature_names=='bineduc')[0][0]

# %%
def func(s):
    s1=s.copy()
    if s1[exposure_index]=='0':
        s1[exposure_index]='1'
    else:
        s1[exposure_index]='0'
    return s1
nb=np.ones(len(feature_names))
nb[exposure_index]=0
nb=nb/nb.sum()

# %%
df_test
# Out:
#           PWGTR PMARST PNURSHM female black hisp SCHLYRS HISPANIC RACE vdori  \
# HHID
# 010003  7797.12    3.0     5.0    1.0   0.0  0.0    16.0      5.0  1.0
# 010004  5847.84    3.0     5.0    1.0   0.0  0.0    12.0      5.0  1.0   4.0
# 010050  5847.84    3.0     5.0    1.0   0.0  0.0    17.0      5.0  7.0   4.0
# 010075  1949.28    3.0     5.0    1.0   0.0  1.0     8.0      2.0  7.0   3.0
# 010147  1949.28    3.0     5.0    1.0   0.0  1.0     8.0      2.0  7.0   3.0
# ...         ...    ...     ...    ...   ...  ...     ...      ...  ...   ...
# 923333  1949.28    2.0     5.0    1.0   0.0  0.0    16.0      5.0  1.0
# 923487  1949.28    4.0     5.0    0.0   1.0  0.0    12.0      5.0  2.0
# 952836  1949.28    2.0     5.0    1.0   0.0  1.0     6.0      2.0  1.0
# 958361  1949.28    2.0     5.0    0.0   1.0  0.0    11.0      5.0  2.0
# 959738      0.0    2.0     5.0    0.0   0.0  0.0    13.0      5.0  0.0   4.0
#
#         ...               PrCIND PrNorm                  Cog  \
# HHID    ...
# 010003  ...                  0.0    0.0  -3.8244876861572266
# 010004  ...                  0.0    1.0   2.1674673080444338
# 010050  ...  0.34309480905532835   0.68   1.2686740589141845
# 010075  ...  0.34309480905532835   0.64   1.2686740589141845
# 010147  ...  0.07624329090118408    0.0  -0.5289124393463132
# ...     ...                  ...    ...                  ...
# 923333  ...                  0.0    0.0  -3.8244876861572266
# 923487  ...                  0.0    0.0  -3.8244876861572266
# 952836  ...                  0.0    0.0  -3.8244876861572266
# 958361  ...                  0.0    0.0  -3.8244876861572266
# 959738  ...  0.26685151815414426   0.72   1.2686740589141845
#
#                       CogSd Hudomiet_classification DEGREE rage_cat     Sex  \
# HHID
# 010003    0.250355988740921                            5.0           Female
# 010004  0.36893764019012454                  Normal    2.0    70-74  Female
# 010050    0.382113379240036                  Normal    5.0    75-79  Female
# 010075   0.3425861620903015                  Normal    0.0    75-79  Female
# 010147    0.303058944940567                Dementia    0.0    80-84  Female
# ...                     ...                     ...    ...      ...     ...
# 923333    0.250355988740921                            4.0           Female
# 923487    0.250355988740921                            2.0             Male
# 952836    0.250355988740921                            0.0           Female
# 958361    0.250355988740921                            1.0             Male
# 959738    0.487519291639328                  Normal    2.0    65-69    Male
#
#                                 RaceAndEthnicity bineduc
# HHID
# 010003                                     White       1
# 010004                                     White       0
# 010050                   All other racial groups       1
# 010075               Hispanic (any racial group)       0
# 010147               Hispanic (any racial group)       0
# ...                                          ...     ...
# 923333                                     White       1
# 923487  Black or African-American (Not Hispanic)       0
# 952836               Hispanic (any racial group)       0
# 958361  Black or African-American (Not Hispanic)       0
# 959738                   All other racial groups       1
#
# [6993 rows x 47 columns]

# %%
def getbp(s):
    # generate a vector summing to 1.0 with zeros where 
    # the response/observation is missing
    # so that we can perturb only in entries which are non-missing
    bp=np.ones(len(s))
    bp[np.where(s=='')[0]]=0
    return bp/bp.sum()

# %%
N=1000
steps=100

# %%
# bad synthetic generation
gensamples_bad=[qsample(s,model,steps=steps,alpha=-1,baseline_prob=getbp(s)) for s in tqdm(X_test[:N])]
ngennoswapq_bad=np.array([qdistance(NULL,s,model,model) for s in tqdm(gensamples_bad)])
gen_noswap_bad_df=pd.DataFrame(gensamples_bad,columns=feature_names)
# Out:
# 100%|███████████████████████████████████████| 1000/1000 [00:34<00:00, 28.61it/s]
# 100%|███████████████████████████████████████| 1000/1000 [00:24<00:00, 40.60it/s]

# %%
# synthetic generation
gensamples=[qsample(s,model,steps=steps,alpha=.97,baseline_prob=getbp(s)) for s in tqdm(X[:N])]
ngennoswapq=np.array([qdistance(NULL,s,model,model) for s in tqdm(gensamples)])
gen_noswap_df=pd.DataFrame(gensamples,columns=feature_names)
# Out:
# 100%|███████████████████████████████████████| 1000/1000 [00:34<00:00, 29.09it/s]
# 100%|███████████████████████████████████████| 1000/1000 [00:26<00:00, 37.57it/s]

# %%
# original
ngennoswap=np.array([qdistance(NULL,s,model,model) for s in tqdm(X_test[:N])])
gen_test_df = pd.DataFrame(X_test[:N],columns=feature_names)
# Out:
# 100%|███████████████████████████████████████| 1000/1000 [00:26<00:00, 38.07it/s]

# %%
# exposure swap generation
gensamples_swap=[qsample(func(s),model,steps=steps,baseline_prob=nb,alpha=.97) for s in tqdm(X_test[:N])]
ngenswap=np.array([qdistance(NULL,s,model,model) for s in tqdm(gensamples_swap)])
gen_swap_df=pd.DataFrame(gensamples_swap,columns=feature_names)
# Out:
# 100%|███████████████████████████████████████| 1000/1000 [00:34<00:00, 29.08it/s]
# 100%|███████████████████████████████████████| 1000/1000 [00:24<00:00, 40.38it/s]

# %%
tmp=syndf.drop('rage',axis=1)
Xsyn=pd.concat([pd.DataFrame(columns=feature_names),tmp]).astype(str).replace('nan','').drop('group',axis=1).values.astype(str)

# %%
syndf=dsynthpop.copy()
ngensynth=np.array([qdistance(NULL,s,model,model) for s in tqdm(Xsyn[:N])])
# Out:
# 100%|███████████████████████████████████████| 1000/1000 [00:24<00:00, 40.16it/s]

# %%
import seaborn as sns
import pylab as plt
sns.distplot(ngennoswap,label='original')
sns.distplot(ngenswap,label='exposure swap')
sns.distplot(ngennoswapq,label='synthetic')
sns.distplot(ngennoswapq_bad,label='bad synthetic')
sns.distplot(ngensynth,label='synthpop')
plt.legend()

# %%
from scipy.stats import ks_2samp

alpha=1e-5
# KS two-sample test
stat, p_val = ks_2samp(ngennoswap,ngennoswapq)
print('comparing original and synthetic data')
print(f"KS Statistic: {stat:.4f}, p-value: {p_val:.4g}")

if p_val < alpha:
    print("Reject null hypothesis: distributions differ.")
else:
    print("Fail to reject null hypothesis: distributions are similar.")
# Out:
# comparing original and synthetic data
# KS Statistic: 0.1900, p-value: 3.43e-16
# Reject null hypothesis: distributions differ.

# %%
# KS two-sample test
stat, p_val = ks_2samp(ngenswap,ngennoswapq)
print('comparing exposure-swapped and synthetic data')
print(f"KS Statistic: {stat:.4f}, p-value: {p_val:.4g}")

if p_val < alpha:
    print("Reject null hypothesis: distributions differ.")
else:
    print("Fail to reject null hypothesis: distributions are similar.")
# Out:
# comparing exposure-swapped and synthetic data
# KS Statistic: 0.3530, p-value: 1.069e-55
# Reject null hypothesis: distributions differ.

# %%
stat, p_val = ks_2samp(ngennoswapq_bad,ngennoswapq)
print('comparing bad-synthetic and synthetic data')
print(f"KS Statistic: {stat:.4f}, p-value: {p_val:.4g}")

if p_val < alpha:
    print("Reject null hypothesis: distributions differ.")
else:
    print("Fail to reject null hypothesis: distributions are similar.")
# Out:
# comparing bad-synthetic and synthetic data
# KS Statistic: 0.7070, p-value: 1.724e-240
# Reject null hypothesis: distributions differ.

# %%
# synthetic dataframe
Ds_=gen_noswap_df
# original dataframe 
D_=df_training.sample(1000)

# %%
# Function to try numeric conversion only if column looks numeric
def safe_to_float(series):
    try:
        # Try converting; if all values become NaN, keep original
        converted = pd.to_numeric(series.replace('', np.nan), errors='coerce')
        if converted.notna().sum() > 0:
            return converted
        else:
            return series
    except:
        return series

# Apply column-wise
D=D_.apply(safe_to_float)
Ds=Ds_.apply(safe_to_float)

# %%
Dm=D.mean(numeric_only=True)
Dv=D.std(numeric_only=True)

# %%
Dsm=Ds.mean(numeric_only=True)
Dsv=Ds.std(numeric_only=True)

# %%
print('mean')
pd.DataFrame({'D':Dm,'Ds':Dsm}).plot(kind='bar',logy=True)
print('std')
pd.DataFrame({'D':Dv,'Ds':Dsv}).plot(kind='bar',logy=True)
# Out:
# mean
# std
# <Axes: >

# %%
! pwd
# Out:
# /home/ishanu/ZED/Research/nsythentic/goodness_of_synthesis/ntb

# %%
import pandas as pd
import pyreadr

# .rds typically stores a single object; grab the first/only value
res = pyreadr.read_r("../../data/synthetic_datasets/synthetic_dataset_40.rds")
obj = next(iter(res.values()))

# If it's a data.frame/tibble, this is a pandas DataFrame already
if isinstance(obj, pd.DataFrame):
    df = obj
else:
    # .rds can hold other objects (vector, list); convert as needed
    # Example: turn an R vector into a DataFrame
    df = pd.DataFrame(obj)

dsynthpop=df.copy()

# %%
dsynthpop.columns
# Out:
# Index(['rage', 'female', 'black', 'hisp', 'SCHLYRS', 'vdori', 'vdlfl1z',
#        'vdlfl2', 'vdlfl3', 'vdwdimmz', 'vdwddelz', 'vdexf7z', 'vdsevens',
#        'vdcount', 'group'],
#       dtype='object')

# %%
feature_names
# Out:
# Index(['PWGTR', 'PMARST', 'PNURSHM', 'female', 'black', 'hisp', 'SCHLYRS',
#        'HISPANIC', 'RACE', 'vdori', 'vdlfl1z', 'vdlfl2', 'vdlfl3', 'vdwdimmz',
#        'vdwddelz', 'vdexf7z', 'vdsevens', 'vdcount', 'nPG014', 'nPG021',
#        'nPG023', 'nPG030', 'nPG040', 'nPG041', 'nPG044', 'nPG047', 'nPG050',
#        'nPG059', 'PD102', 'jorm', 'vs1hcapdx', 'vs1hcapdxeap', 'nonzeroweight',
#        'inHCAP', 'age65up', 'cogfunction2016', 'PrDem', 'PrCIND', 'PrNorm',
#        'Cog', 'CogSd', 'Hudomiet_classification', 'DEGREE', 'rage_cat', 'Sex',
#        'RaceAndEthnicity', 'bineduc'],
#       dtype='object')

# %%
dsynthpop.vdwddelz.mean()
# Out:
# 0.3985081652274783

# %%
D.vdwddelz.mean()
# Out:
# 0.43033022168853646

# %%
Ds.vdwddelz.mean()
# Out:
# 0.45017007277776355

# %%
sns.distplot(dsynthpop.sample(1000).vdwddelz,label='synthpop')
sns.distplot(D.vdwddelz,label='original')
sns.distplot(Ds.vdwddelz,label='lsm')
plt.legend()

# %%
sns.distplot(dsynthpop.sample(1000).vdori,label='synthpop')
sns.distplot(D.vdori,label='original')
sns.distplot(Ds.vdori,label='lsm')
plt.legend()

# %%
D.corr(numeric_only=True)
# Out:
#                     PWGTR    PMARST   PNURSHM    female     black      hisp  \
# PWGTR            1.000000 -0.154682  0.069440 -0.103883 -0.272626 -0.157664
# PMARST          -0.154682  1.000000 -0.051333  0.207523  0.204650  0.007359
# PNURSHM          0.069440 -0.051333  1.000000 -0.029087 -0.013907  0.005358
